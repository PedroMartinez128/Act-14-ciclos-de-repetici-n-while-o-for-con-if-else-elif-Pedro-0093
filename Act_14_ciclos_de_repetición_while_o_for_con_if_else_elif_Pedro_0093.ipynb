# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroMartinez128/Act-14-ciclos-de-repetici-n-while-o-for-con-if-else-elif-Pedro-0093/blob/main/Act_14_ciclos_de_repetici%C3%B3n_while_o_for_con_if_else_elif_Pedro_0093.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Pedro Martinez NL = 38
# #### CBTIS#128
# #### Inteligencia Artificial
# #### Grupo 2-H
# #### Sub-Modulo:Elabora Proyectos Con Programacion Logica
# #### Docente: Ing. Eliseo Nava
# ---
# #### Redaccion del Problema No.38
# ##### Programa que calcule el Mínimo Común Múltiplo (MCM) de dos números enteros positivos usando un bucle de búsqueda o la relación con el MCD.
# #### Prompt
# #### Lenguaje de programación:Python
# #### Puedes generar un Programa que calcule el Mínimo Común Múltiplo (MCM) de dos números enteros positivos usando un bucle de búsqueda o la relación con el MCD.
#
# * OJO no funciones, no programación orientada a objetos, no listas, no diccionarios, no try.

# %%
# 1. 📥 ENTRADA DE DATOS y 🛡️ VALIDACIÓN (Uso de if-else)
print("🧮 --- CALCULADORA DE MCD Y MCM --- 🧮\n")

a = int(input("Introduce el primer número entero positivo: 🔢 "))
b = int(input("Introduce el segundo número entero positivo: 🔢 "))

# Verificamos que ambos números sean estrictamente mayores que cero
if a <= 0 or b <= 0:
    print("\n❌ ¡Error! Ambos números deben ser enteros POSITIVOS y mayores que cero ( > 0 ).")
    print("🔄 Por favor, ejecuta el programa de nuevo e inténtalo otra vez. 🔄")
else:
    # Guardamos los valores originales para el cálculo final
    num1 = a
    num2 = b

    # 2. ⚙️ PROCESO (Bucle para encontrar el MCD con el Algoritmo de Euclides)
    while b != 0:
        residuo = a % b
        a = b
        b = residuo

    # Al salir del bucle, 'a' es el MCD
    mcd = a

    # Calculamos el MCM usando la relación matemática con el MCD
    mcm = (num1 * num2) // mcd

    # 3. 📤 SALIDA DE RESULTADOS
    print("\n-------------------------------------------")
    print(f"🎉 ¡Cálculo completado con éxito para {num1} y {num2}! 🎉")
    print("-------------------------------------------")
    print(f"🔍 El Máximo Común Divisor (MCD) es: ✨ {mcd} ✨")
    print(f"🚀 El Mínimo Común Múltiplo (MCM) es: ✨ {mcm} ✨")
    print("-------------------------------------------")
# Out:
# 🧮 --- CALCULADORA DE MCD Y MCM --- 🧮
#
# Introduce el primer número entero positivo: 🔢 6
# Introduce el segundo número entero positivo: 🔢 4
#
# -------------------------------------------
# 🎉 ¡Cálculo completado con éxito para 6 y 4! 🎉
# -------------------------------------------
# 🔍 El Máximo Común Divisor (MCD) es: ✨ 2 ✨
# 🚀 El Mínimo Común Múltiplo (MCM) es: ✨ 12 ✨
# -------------------------------------------

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/PedroMartinez128/Act-14-ciclos-de-repetici-n-while-o-for-con-if-else-elif-Pedro-0093/refs/heads/main/InfoMACoMu.png)
